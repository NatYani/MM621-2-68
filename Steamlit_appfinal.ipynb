# %% [markdown]
# <a href="https://colab.research.google.com/github/NatYani/MM621-2-68/blob/main/Steamlit_appfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Streamlit if it's not already installed
# !pip install streamlit

import streamlit as st

# %%
import streamlit as st
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import RandomForestClassifier

# %%
st.set_page_config(page_title='Customer Churn Prediction', layout='wide', page_icon=":bar_chart:")
# Out:
# 2026-04-18 11:04:59.775 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
def create_mock_data(filename='customer_churn_mock.csv'):
    np.random.seed(42)
    n_samples = 1000
    data = {
        'CustomerID': range(1, n_samples + 1),
        'Age': np.random.randint(18, 70, n_samples),
        'Tenure_Months': np.random.randint(1, 72, n_samples),
        'Monthly_Charge': np.random.uniform(500, 3000, n_samples).round(2),
        'Support_Tickets': np.random.randint(0, 6, n_samples)
        }
    df = pd.DataFrame(data)

    churn_prob = (
        (df['Support_Tickets'] * 0.12) +
         (1 / (df['Tenure_Months'] + 1)) * 0.4 +
          (df['Monthly_Charge'] / 3000) * 0.1
        )
    df['Churn'] = (np.random.rand(n_samples) < churn_prob).astype(int)
    df.to_csv(filename, index=False)
    return df

# %%
import streamlit as st
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import RandomForestClassifier

#เก็บ Data คล้ายกับรู้ว่าลูกค้าจะสั่งผัดกะเพราละทำไว้ ถ้าลูกค้าสั่งก็สามารถเสิร์ฟได้เลย
@st.cache_data
def train_model():
  if not os.path.exists('customer_churn_mock.csv'):
    df = create_mock_data()
  else:
    df = pd.read_csv('customer_churn_mock.csv')

  #เอาทุกวันยกเว้น churn column เดียว
  X = df[['Age', 'Tenure_Months', 'Monthly_Charge', 'Support_Tickets']]
  y = df['Churn']

  #รันโมเดล
  model = RandomForestClassifier(n_estimators=100, random_state=42)
  model.fit(X, y)
  return model

model = train_model()
# Out:
# 2026-04-18 11:04:59.796 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-18 11:04:59.799 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-18 11:04:59.800 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#การออกแบบส่วนแสดงผล (User Interface) ที่จะใช้บน Streamlit
st.set_page_config(page_title='Customer Churn Prediction', layout='wide', page_icon=":bar_chart:")

st.title(":bar_chart: Customer Churn Prediction by [บุณิกา_6802115052]")
st.markdown("แอปพลิเคชั่นสำหรับทีมการตลาด **ประเมินความเสี่ยง** และ **จัดแคมเปญรักษาลูกค้า** เชิงรุก")
st.divider()
# Out:
# 2026-04-18 11:05:00.399 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.402 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.756
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-04-18 11:05:00.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
#การออกแบบส่วนแสดงผลแถบด้านข้าง (Sidebar) ที่จะใช้บน Streamlit สำหรับกรอกข้อมูลนำเข้า
st.sidebar.header("📝กรอกข้อมูลนำเข้า")

age = st.sidebar.slider("อายุ (ปี)", 18, 70, 35)
tenure = st.sidebar.slider("จำนวนเดือนที่ใช้บริการ (เดือน)", 1, 72, 6)
charge = st.sidebar.number_input("ค่าใช้จ่ายต่อเดือน (เดือน)", 500.00, 3000.00, 1500.00, step=10.0)
tickets = st.sidebar.selectbox("จำนวนครั้งที่ติดต่อฝ่าย Support (Support Ticket)", [0, 1, 2, 3, 4, 5])
# Out:
# 2026-04-18 11:05:00.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
#ทำนายผล
input_data = pd.DataFrame({
    'Age': [age],
    'Tenure_Months': [tenure],
    'Monthly_Charge': [charge],
    'Support_Tickets': [tickets]
})

prediction = model.predict(input_data)
probability = model.predict_proba(input_data)[0][1]

# %%
#การแสดงผลของการทำนายผล
st.subheader("💡ผลการวิเคราะห์และข้อเสนอทางธุรกิจ")

if prediction == 1:
  st.error(f"⚠️ มีความเสี่ยงสูงที่ลูกค้ารายนี้ยกเลิกบริการ ({probability:.1%})")
  st.markdown("ACTION PLAN")
  st.info("""
  * **Retention Offer:** ส่ง SMS มอบคูปองส่วนลด 20% สำหรับรอบบิลถัดไป
  * **Proactive Service:** ให้ทีม Customer Success โทรสอบถามปัญหาการใช้งานโดยด่วน
  * **Expected ROI:** ค่าใช้จ่ายในการโทร+ส่วนลด คุ้มค่ากว่าการหาลูกค้าใหม่
  """)
else:
  st.error(f"✅ มีความเสี่ยงน้อยที่ลูกค้ารายนี้มีแนวโน้มใช้งานต่อ (โดยมีความเสี่ยงเพียง {probability:.1%})")

  st.markdown("ACTION PLAN")
  st.info("""
 * **Relationship Building:** ส่งอีเมลขอบคุณสำหรับการใช้งานอย่างต่อเนื่อง
 * **Cross-sell Opportunity:** เสนอแพ็กเกจเสริม (Add-on) ที่เข้ากับพฤติกรรมการใช้งาน
  """)
# Out:
# 2026-04-18 11:05:00.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 11:05:00.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
